# %%
# Neel Patel - Profusion Data Analyst Assessment
# May 2021

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df1 = pd.read_csv('house_dataset1.csv')
df2 = pd.read_csv('house_dataset2.csv')

# %%
df1.head()
# Out:
#    price  area  number_of_bedrooms  pieces_of _furniture
# 0    510    35                   1                     7
# 1    490    30                   1                     8
# 2    470    32                   1                     7
# 3    460    31                   1                     6
# 4    500    36                   1                     6

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   price                 150 non-null    int64
#  1   area                  150 non-null    int64
#  2   number_of_bedrooms    150 non-null    int64
#  3   pieces_of _furniture  150 non-null    int64
# dtypes: int64(4)
# memory usage: 4.8 KB

# %%
df2.head()
# Out:
#    price  area  number_of_bedrooms  pieces_of _furniture
# 0    510    35                   1                     7
# 1    490    30                   1                     8
# 2    470    32                   1                     7
# 3    460    31                   1                     6
# 4    500    36                   1                     6

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   price                 150 non-null    int64
#  1   area                  150 non-null    int64
#  2   number_of_bedrooms    150 non-null    int64
#  3   pieces_of _furniture  150 non-null    int64
# dtypes: int64(4)
# memory usage: 4.8 KB

# %%
corr1 = df1.corr()
corr1
# Out:
#                          price      area  number_of_bedrooms  \
# price                 1.000000 -0.195784            0.779442
# area                 -0.195784  1.000000           -0.404972
# number_of_bedrooms    0.779442 -0.404972            1.000000
# pieces_of _furniture  0.064048  0.107240            0.044286
#
#                       pieces_of _furniture
# price                             0.064048
# area                              0.107240
# number_of_bedrooms                0.044286
# pieces_of _furniture              1.000000

# %%
sns.heatmap(corr1)

# %%
corr2 = df2.corr()
corr2
# Out:
#                          price      area  number_of_bedrooms  \
# price                 1.000000 -0.195784            0.779442
# area                 -0.195784  1.000000           -0.404972
# number_of_bedrooms    0.779442 -0.404972            1.000000
# pieces_of _furniture  0.205031 -0.104977            0.145227
#
#                       pieces_of _furniture
# price                             0.205031
# area                             -0.104977
# number_of_bedrooms                0.145227
# pieces_of _furniture              1.000000

# %%
sns.heatmap(corr2)

# %%
data1 = df1.copy()
y = data1['price']
X = data1.drop(['price'], axis = 1)

# %%
from statsmodels.api import OLS
OLS(y, X).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.989
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                     4512.
# Date:                Fri, 14 May 2021   Prob (F-statistic):          1.87e-144
# Time:                        18:04:06   Log-Likelihood:                -829.88
# No. Observations:                 150   AIC:                             1666.
# Df Residuals:                     147   BIC:                             1675.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
data2 = df2.copy()
y = data2['price']
X = data2.drop(['price'], axis = 1)

# %%
from statsmodels.api import OLS
OLS(y, X).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                     4714.
# Date:                Fri, 14 May 2021   Prob (F-statistic):          7.79e-146
# Time:                        18:04:19   Log-Likelihood:                -826.63
# No. Observations:                 150   AIC:                             1659.
# Df Residuals:                     147   BIC:                             1668.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
df1.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF73CC5B38>,
# ...
#       dtype=object)

# %%
df2.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF73CC5390>,
# ...
#       dtype=object)

# %%
for col in df1.columns:
    plt.scatter(df1[col], df1.price, label=col)
    plt.legend()
    plt.xlabel(col)
    plt.ylabel('price')
    plt.title(col)
    plt.show()

# %%
for col in df2.columns:
    plt.scatter(df2[col], df2.price, label=col)
    plt.legend()
    plt.xlabel(col)
    plt.ylabel('price')
    plt.title(col)
    plt.show()

# %%
    plt.scatter(df2.number_of_bedrooms, df2.area)
    plt.legend()
    plt.xlabel('Number of bedrooms')
    plt.ylabel('Area')
    plt.title('Area vs bedrooms')
    plt.show()

# %%
# Average area for 1 bedrooms is higher than 2 and 3 bedroom houses - penthouses?

# %%
print("1 bedroom mean area: " + str(df1.loc[df1['number_of_bedrooms'] == 1 ]['area'].mean()))
print("1 bedroom mean area: " + str(df1.loc[df1['number_of_bedrooms'] == 1 ]['area'].median()))
# Out:
# 1 bedroom mean area: 34.28
# 1 bedroom mean area: 34.0

# %%
print("2 bedroom mean area: " + str(df1.loc[df1['number_of_bedrooms'] == 2 ]['area'].mean()))
print("2 bedroom median area: " + str(df1.loc[df1['number_of_bedrooms'] == 2 ]['area'].median()))
# Out:
# 2 bedroom mean area: 27.6056338028169
# 2 bedroom median area: 28.0

# %%
print("3 bedroom mean area: " + str(df1.loc[df1['number_of_bedrooms'] == 3 ]['area'].mean()))
# Out:
# 3 bedroom mean area: 30.482758620689655
# 3 bedroom median area: 30.0

# %%
one_bed_avg = df1.loc[df1['number_of_bedrooms'] == 1 ]['price'].mean()

# %%
two_bed_avg = df1.loc[df1['number_of_bedrooms'] == 2 ]['price'].mean()

# %%
three_bed_avg = df1.loc[df1['number_of_bedrooms'] == 3 ]['price'].mean()

# %%
# median price for each bedroom
print(df1.loc[df1['number_of_bedrooms'] == 1 ]['price'].median())
print(df1.loc[df1['number_of_bedrooms'] == 2 ]['price'].median())
print(df1.loc[df1['number_of_bedrooms'] == 3 ]['price'].median())
# Out:
# 500.0
# 600.0
# 670.0

# %%
# mean price for each bedroom
print(one_bed_avg)
print(two_bed_avg)
print(three_bed_avg)
# Out:
# 500.6
# 605.4929577464789
# 676.8965517241379

# %%
average_increase = (two_bed_avg - one_bed_avg) + (three_bed_avg - two_bed_avg) / 2

# %%
average_increase
# Out:
# 140.59475473530836

# %%
import seaborn as sns
sns.set_theme(style="white")

# area against number of bedrooms with price
sns.relplot(x="area", y="price", size="number_of_bedrooms",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=df1)

# %%
df = df1[['price','area']]

# %%
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(df)
    distortions.append(kmeanModel.inertia_)

# %%
plt.figure(figsize=(16,8))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
k_means = KMeans(n_clusters = 3)
k_means.fit(df)
y_hat = k_means.predict(df)

# %%
ax = plt.axes()
ax.set_facecolor("orange")
plt.scatter(df['price'], df['area'], c = y_hat, s = 25)
cl_centers = k_means.cluster_centers_
plt.scatter(cl_centers[:, 0], cl_centers[:, 1], c='black', s=100);
plt.xlabel('Price')
plt.ylabel('Area')
plt.show()

# %% [markdown]
# ## initial look at the email and survey dataframes

# %%
email_df = pd.read_csv('email_data.csv')
survey_df = pd.read_csv('survey_data.csv')

# %%
email_df
# Out:
#       Week      Type Customer segment  Emails delivered  Unique opens  \
# 0   Week 1    Invite          Group 1               276            54
# 1   Week 3    Invite          Group 1               155            31
# 2   Week 2  Reminder          Group 1               127            22
# 3   Week 2    Invite          Group 1               140            32
# 4   Week 1  Reminder          Group 2              1221           284
# 5   Week 1  Reminder          Group 1               257            38
# 6   Week 1    Invite          Group 2              1262           382
# 7   Week 4    Invite          Group 1               164            50
# 8   Week 3  Reminder          Group 1               148            28
# 9   Week 3    Invite          Group 2              1138           316
# 10  Week 2    Invite          Group 2              1165           341
# 11  Week 2  Reminder          Group 2              1130           263
# ...

# %% [markdown]
# ##	Questions
# 1)	How are the different customer groups responding to the email campaigns? How engaged are they with the emails?
#
# 2)	How does the performance of the email campaigns change over time for each customer segment?
#
# 3)	How engaged are the customers with the survey?
#
# 4)	In which questions do people drop out of the survey? (top 5 is enough)

# %%
print(email_df.groupby(['Customer segment', 'Type'])['Emails delivered'].sum())
# Out:
# Customer segment  Type
# Group 1           Invite       735
#                   Reminder     682
# Group 2           Invite      4705
#                   Reminder    4572
# Group 3           Invite      2333
#                   Reminder    2108
# Name: Emails delivered, dtype: int64

# %%
survey_df
# Out:
#      Customer ID     Status    Week End question Customer segment
# 0            854  Completed  Week 2    Thank you          Group 3
# 1            526  Completed  Week 1    Thank you          Group 2
# 2            294    Stopped  Week 1           Q1          Group 2
# 3            477  Completed  Week 3    Thank you          Group 3
# 4            278  Completed  Week 3    Thank you          Group 3
# ..           ...        ...     ...          ...              ...
# 734          897  Completed  Week 4    Thank you          Group 3
# 735          160    Stopped  Week 4           Q7          Group 3
# 736          318  Completed  Week 4    Thank you          Group 2
# 737          518  Completed  Week 4    Thank you          Group 3
# 738          325  Completed  Week 4    Thank you          Group 2
#
# [739 rows x 5 columns]

# %%
survey1 = pd.DataFrame(survey_df.groupby(['Status', 'End question'])['Customer ID'].count())

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 739 entries, 0 to 738
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer ID       739 non-null    int64
#  1   Status            739 non-null    object
#  2   Week              739 non-null    object
#  3   End question      739 non-null    object
#  4   Customer segment  739 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 29.0+ KB

# %%
survey_df['Status'].value_counts()
# Out:
# Completed    533
# Stopped      206
# Name: Status, dtype: int64

# %%
survey1
# Out:
#                         Customer ID
# Status    End question
# Completed Thank you             533
# Stopped   Q1                      6
#           Q10                    11
#           Q11                     8
#           Q12                     8
#           Q13                     1
#           Q14                     1
#           Q2                     35
#           Q3                     16
#           Q4                     53
#           Q5                     15
#           Q6                      2
#           Q7                     27
#           Q8                     16
#           Q9                      7
